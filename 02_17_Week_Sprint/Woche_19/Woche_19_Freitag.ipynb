# %% [markdown]
# # Woche 19 – Freitag: Abschluss Netzwerkanalyse & Ausblick
#
# ## Block 1 (06:00 – 08:45): Zusammenfassung Netzwerkanalyse
#
# **Aufgabe:** Erstellen Sie eine Mindmap in STEM, die die folgenden Konzepte verbindet: Graph (gerichtet/ungerichtet), Zentralitätsmaße, Zyklen, Community Detection, bipartite Graphen, PageRank.
#
# ---
#
# ## Block 2 (09:30 – 11:40): Python – Pipeline für Netzwerkanalyse in AML
#
# **Aufgabe:** Schreiben Sie eine Funktion `analyze_network(edges)`, die einen Graphen erstellt und folgende Werte berechnet:
# - Anzahl der Knoten und Kanten
# - Durchschnittlicher Grad
# - Anzahl der Gemeinschaften (Louvain)
# - Knoten mit höchster Betweenness‑Zentralität
#
# Testen Sie die Funktion mit Ihren Daten oder einem synthetischen Graphen.

# %%
def analyze_network(edge_list):
    G = nx.Graph()
    G.add_edges_from(edge_list)
    # Implementieren Sie hier die Analyse
    pass

# Beispiel
# edges = [(1,2), (2,3), (3,4), (4,1), (2,4)]
# analyze_network(edges)

# %% [markdown]
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Abschluss Netzwerkanalyse & AI Act
#
# **Aufgabe:** Beantworten Sie in GOV: Welche Anforderungen des AI Act (insb. Art. 13, 15) sind bei der Verwendung von Graph‑Algorithmen im AML‑Kontext besonders relevant? Wie stellen Sie die Robustheit und Cybersicherheit sicher?
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Abschluss Netzwerkanalyse – Grammatikmix
#
# Schreiben Sie einen Aufsatz (1 Seite) über die Bedeutung der Netzwerkanalyse für die Geldwäschebekämpfung. Verwenden Sie alle gelernten Grammatikstrukturen. Speichern Sie als `netzwerk_grammatik_mix.md` in Track_C.
