# %% [markdown]
# # Woche 19 – Donnerstag: Wiederholung & Anwendung auf Transaktionsdaten
#
# ## Block 1 (06:00 – 08:45): Theoretische Wiederholung
#
# **Aufgaben:**
# 1. Was ist der Unterschied zwischen Degree‑, Betweenness‑ und Closeness‑Zentralität?
# 2. Wie kann man Zyklen in einem gerichteten Graphen nutzen, um Smurfing zu erkennen?
# 3. Wozu dient Community Detection?
#
# ---
#
# ## Block 2 (09:30 – 11:40): Anwendung auf Ihre AML‑Transaktionsdaten
#
# **Aufgabe:** Erstellen Sie aus Ihren `cleaned_aml_batch.json`‑Daten einen Graphen. Knoten sind die `account_protected` (maskierte Konten), Kanten werden durch Transaktionen zwischen Konten gebildet (gleiche `tx_id`?). Da Ihre Daten keine direkten Verbindungen zwischen Konten enthalten, erzeugen Sie synthetische Verbindungen oder verwenden Sie einen öffentlichen Datensatz. Führen Sie eine Community‑Detection durch.

# %%
import pandas as pd
df = pd.read_json('cleaned_aml_batch.json')
# Hier müssten Sie Kanten zwischen Konten definieren (z. B. wenn sie in derselben Transaktion vorkommen)
# Da dies hier nicht direkt möglich ist, ist dies eine Skizze.
print("Daten geladen. Erstellen Sie einen Graphen basierend auf Ihren Daten.")

# %% [markdown]
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Fallstudie: Netzwerkanalyse in der Praxis
#
# **Aufgabe:** Recherchieren Sie einen echten Fall, in dem Netzwerkanalyse zur Aufdeckung von Geldwäsche eingesetzt wurde (z. B. Operation „Green Light“). Notieren Sie die Erkenntnisse in GOV.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Adverbialsätze in Netzwerkberichten
#
# **Übung:** Bilden Sie 10 Sätze mit adverbialen Nebensätzen zum Thema „Netzwerkanalyse in der AML‑Überwachung“. Beispiel: „Nachdem die Community‑Detection durchgeführt wurde, werden die verdächtigen Gruppen isoliert betrachtet.“
