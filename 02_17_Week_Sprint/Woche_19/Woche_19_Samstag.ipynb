# %% [markdown]
# # Woche 19 – Samstag: Leichte Wiederholung Netzwerkanalyse
#
# 1. Wiederholen Sie die Zentralitätsmaße und wenden Sie sie auf einen selbst erstellten Graphen an.
# 2. Laden Sie einen öffentlichen Graphen (z. B. `nx.karate_club_graph()`) und berechnen Sie die PageRank‑Werte.
# 3. Lesen Sie einen Fachartikel zu „Graph Neural Networks for AML“ (z. B. auf arXiv) und notieren Sie die wichtigsten Erkenntnisse in GOV.
# 4. Bilden Sie 10 Sätze mit Passiv‑Ersatzformen zum Thema „Netzwerkanalyse in der Bank“.
# 5. Reflektieren Sie in SPR: Wie können Sie die Netzwerkanalyse in Ihr bestehendes AML‑Portfolio integrieren?
#
# ---
# **Sonntag:** frei.
