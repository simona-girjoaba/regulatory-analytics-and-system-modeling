# %% [markdown]
# # Woche 3 – Samstag: Wiederholung
#
# **Mathematik:**
# - Wiederholen Sie die SVD‑Zerlegung: Schreiben Sie die Formel $A = U\Sigma V^T$ auf und erklären Sie die Bedeutung von $U$, $\Sigma$, $V$.
# - Führen Sie PCA auf einem kleinen Datensatz (z. B. 5 Punkte in 2D) per Hand durch (zentrieren, Kovarianzmatrix, Eigenwerte).
#
# **Governance:**
# - Lesen Sie Ihre Checkliste zu Art. 6‑10 und prüfen Sie, ob alle Punkte verständlich sind.
# - Hören Sie einen Podcast zu „Hochrisiko‑KI im Finanzsektor“.
#
# **Sprache:**
# - Bilden Sie 10 Sätze mit Relativsätzen zu den Themen SVD und PCA.
#
# **Deutsch (Hueber):** Lektion zu Relativsätzen wiederholen.
#
# ---
# **Sonntag:** komplett lernfrei.
