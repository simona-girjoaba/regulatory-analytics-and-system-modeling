# %% [markdown]
# # Woche 3 – Donnerstag: Wiederholung SVD/PCA & Daten‑Governance‑Protokoll
#
# ## Block 1 (06:00 – 08:45): Wiederholung SVD und PCA
#
# **Aufgaben:**
# 1. Berechnen Sie die SVD einer $3\times2$ Matrix Ihrer Wahl.
# 2. Führen Sie PCA auf einem kleinen Datensatz (z. B. `iris`) durch und interpretieren Sie die Loadings.
# 3. Erstellen Sie eine Mindmap in STEM: Zusammenhang zwischen SVD, PCA und Ausreißererkennung.

# %%
from sklearn.datasets import load_iris
import pandas as pd
iris = load_iris()
X_iris = iris.data
pca_iris = PCA(n_components=2)
X_iris_pca = pca_iris.fit_transform(X_iris)
print("Erklärte Varianz:", pca_iris.explained_variance_ratio_)
print("Loadings:\n", pca_iris.components_)

# %% [markdown]
# ## Block 2 (09:30 – 11:40): Erstellung eines Daten‑Governance‑Protokolls
#
# **Lernziel:** Sie entwerfen ein Protokoll gemäß Art. 10 für Ihr AML‑System.
#
# **Inhalt des Protokolls (1‑2 Seiten):**
# - Beschreibung der Datenquellen (Transaktionslogs)
# - Maßnahmen zur Sicherstellung der Datenqualität (Plausibilisierung, Behandlung fehlender Werte)
# - Repräsentativität (zeitlicher Abdeckung, Auswahlkriterien)
# - Schutz personenbezogener Daten (Anonymisierung, Pseudonymisierung)
#
# Speichern Sie das Protokoll als:
# `01_Master_Curriculum_DS_ML/Track_C_Governance_and_Compliance/12_daten_governance_protokoll.md`

# %% [markdown]
# ## Block 3 (12:40 – 14:10): Diskussion – Herausforderungen der Daten‑Governance im AML‑Kontext
#
# Beantworten Sie in GOV folgende Fragen:
# - Wie gehen Sie mit unausgeglichenen Klassen um (viele normale Transaktionen, wenige verdächtige)?
# - Wie oft müssen die Daten aktualisiert werden?
# - Wer ist für die Datenqualität verantwortlich?
#
# ---
#
# ## Block 4 (14:40 – 16:50): Relativsätze – Abschlussübung
#
# Buscha, Kap. 6.7, Abschlusstest. Bilden Sie 20 Sätze, die Relativsätze enthalten, zu den Themen PCA, Ausreißererkennung und AI Act. Notieren Sie sie in SPR.
