# %% [markdown]
# # Woche 16 – Dienstag: Wiederholung Maßtheorie, Integration, Risikomaße
#
# ## Block 1 (06:00 – 08:45): Maßtheorie und Integration
#
# **Aufgabe 1:** Definieren Sie das äußere Maß $\lambda^*(A)$. Welche Eigenschaften hat es?
#
# **Aufgabe 2:** Wann heißt eine Menge Lebesgue‑messbar? (Carathéodory‑Bedingung)
#
# **Aufgabe 3:** Formulieren Sie den Satz von der monotonen Konvergenz (Beppo Levi) und den Satz von der dominierten Konvergenz (Lebesgue).
#
# **Aufgabe 4:** Was sind $L^p$‑Räume? Für welches $p$ erhält man einen Hilbertraum?
#
# ---
#
# ## Block 2 (09:30 – 11:40): Risikomaße (VaR, ES, Copulas)
#
# **Aufgabe 1:** Definieren Sie den Value‑at‑Risk (VaR) und den Expected Shortfall (ES).
#
# **Aufgabe 2:** Warum ist ES kohärent, VaR jedoch nicht? (Erklären Sie die Subadditivität.)
#
# **Aufgabe 3:** Was ist eine Copula? Skizzieren Sie das Theorem von Sklar.
#
# **Aufgabe 4:** Berechnen Sie VaR und ES für einen normalverteilten Datensatz (Ihre Wahl) mit Python.
#
# > **Verbesserungshinweis:** Nutzen Sie Ihre Notebooks aus Woche 6 und 9 zur Wiederholung.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Wiederholung AI Act (Technische Dokumentation, Notifizierte Stellen, Art. 11‑15, 28‑39)
#
# **Aufgabe:** Beantworten Sie folgende Fragen in GOV:
# 1. Was muss eine technische Dokumentation gemäß Art. 11 enthalten?
# 2. Wie lange müssen Logs aufbewahrt werden (Art. 12)?
# 3. Was verlangt Art. 13 zur Cybersicherheit?
# 4. Was ist der Unterschied zwischen einer notifizierenden und einer notifizierten Stelle (Art. 28‑31)?
# 5. Welche Pflichten hat eine notifizierte Stelle (Art. 32‑35)?
# 6. Was muss bei einem schwerwiegenden Vorfall gemeldet werden (Art. 36)?
#
# Speichern Sie Ihre Antworten als `103_wiederholung_ai_act_technik.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Wiederholung Grammatik (Adverbialsätze, Passiv, Passiv‑Ersatzformen)
#
# **Aufgabe:** Schreiben Sie einen kurzen Aufsatz (1 Seite) über die Bedeutung der technischen Dokumentation für die Konformität. Verwenden Sie:
# - 10 Adverbialsätze (kausal, temporal, konditional, konzessiv)
# - 10 Vorgangspassiv‑Sätze
# - 10 Zustandspassiv‑Sätze
# - 10 Passiv‑Ersatzformen („sich lassen“, „sein + zu + Infinitiv“)
#
# Speichern Sie als `104_grammatik_wiederholung_2.md` in Track_C.
