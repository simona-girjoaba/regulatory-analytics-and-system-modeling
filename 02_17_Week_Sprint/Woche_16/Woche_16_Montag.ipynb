# %% [markdown]
# # Woche 16 – Montag: Wiederholung Mathematik (Wochen 1‑7)
#
# ## Block 1 (06:00 – 08:45): Vektorräume, Normen, Metriken, Matrizen
#
# **Aufgabe 1:** Schreiben Sie die acht Vektorraumaxiome auf. Geben Sie ein Beispiel für einen Vektorraum und ein Gegenbeispiel.
#
# **Aufgabe 2:** Definieren Sie die $\ell_1$-, $\ell_2$- und $\ell_\infty$-Norm. Berechnen Sie alle drei für $x = (1, -2, 3)$.
#
# **Aufgabe 3:** Was ist eine Metrik? Welche Beziehung besteht zwischen Norm und Metrik?
#
# **Aufgabe 4:** Berechnen Sie das Produkt $A \cdot B$ und die Inverse von $A$ (falls existent) für $A = \begin{pmatrix}2&1\\1&1\end{pmatrix}$, $B = \begin{pmatrix}1&0\\2&1\end{pmatrix}$.
#
# > **Verbesserungshinweis:** Wiederholen Sie bei Unsicherheiten die entsprechenden Wochen (Woche 1‑2).
#
# ---
#
# ## Block 2 (09:30 – 11:40): SVD, PCA, Zeitreihen (Woche 3, 7, 13)
#
# **Aufgabe 1:** Schreiben Sie die SVD‑Zerlegung $A = U\Sigma V^T$ hin und erklären Sie die Bedeutung von $U$, $\Sigma$, $V$.
#
# **Aufgabe 2:** Erklären Sie, wie PCA zur Dimensionsreduktion genutzt wird. Welche Rolle spielen die Singulärwerte?
#
# **Aufgabe 3:** Was ist der Unterschied zwischen ARIMA und SARIMA? Wann benötigt man die saisonale Erweiterung?
#
# **Aufgabe 4:** Wie interpretieren Sie ACF und PACF? Was sagt der Ljung‑Box‑Test aus?
#
# > **Verbesserungshinweis:** Nutzen Sie Ihre Notebooks aus Woche 3, 7 und 13 zur Wiederholung.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Wiederholung AI Act (Grundlagen, Hochrisiko‑KI, Art. 1‑21)
#
# **Aufgabe:** Beantworten Sie folgende Fragen in GOV:
# 1. Was sind die Ziele des AI Act (Art. 1)?
# 2. Wann fällt ein KI‑System unter den Anwendungsbereich (Art. 2)?
# 3. Definieren Sie die Begriffe „KI‑System“, „Anbieter“, „Betreiber“ (Art. 3).
# 4. Was verbietet Art. 5?
# 5. Wann ist ein KI‑System eine Hochrisiko‑KI (Art. 6)?
# 6. Welche Pflichten hat der Anbieter (Art. 16‑18)?
#
# Speichern Sie Ihre Antworten als `101_wiederholung_ai_act_grundlagen.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Wiederholung Grammatik (Nominalisierungen, Partizipialattribute, Relativsätze)
#
# **Aufgabe:** Nehmen Sie einen Ihrer Berichte aus den Wochen 1‑4 und überarbeiten Sie ihn, indem Sie:
# - 10 Verben nominalisieren
# - 10 Partizipialattribute einfügen
# - 10 Relativsätze einbauen
#
# Speichern Sie die überarbeitete Version als `102_grammatik_wiederholung_1.md` in Track_C.
