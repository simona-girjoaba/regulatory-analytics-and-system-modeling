# %% [markdown]
# # Woche 16 – Freitag: Bewerbungsabschluss & Portfolio‑Finalisierung
#
# ## Block 1 (06:00 – 08:45): Bewerbungsunterlagen finalisieren
#
# **Aufgabe:** Bereiten Sie die vollständigen Bewerbungsunterlagen für uni‑assist vor:
# - Motivationsschreiben (letzte Korrektur)
# - Lebenslauf (aktualisiert, mit Link zum GitHub‑Portfolio)
# - Bachelorzeugnis (beglaubigte Kopie, ggf. Übersetzung)
# - Deutsch‑Sprachnachweis (mindestens B2, für die spätere Einschreibung DSH‑2)
# - Passkopie
# - ggf. weitere geforderte Dokumente (siehe THM‑Webseite)
#
# **Speichern Sie alle Dokumente in einem Ordner `Bewerbung_THM` außerhalb des Sprint‑Ordners.**
#
# > **Verbesserungshinweis:** Die Frist für internationale Bewerber endet am 15. Juli. Reichen Sie die Unterlagen **mindestens zwei Wochen vorher** ein, da die Bearbeitung durch uni‑assist Zeit benötigt.
#
# ---
#
# ## Block 2 (09:30 – 11:40): GitHub‑Portfolio – Letzte Feinschliffe
#
# **Aufgabe:** Überprüfen Sie Ihr GitHub‑Repository:
# - Alle Notebooks sollten ausgeführt sein (Zellen in der richtigen Reihenfolge).
# - Entfernen Sie überflüssige Ausgaben (z. B. zu viele `print` in Schleifen).
# - Achten Sie auf eine einheitliche Benennung der Dateien.
# - Ergänzen Sie eine `README.md` auf der obersten Ebene des Sprint‑Ordners mit einer kurzen Beschreibung des Projekts.
# - Erstellen Sie ein **Release** (z. B. `v1.0 – 17‑Wochen‑Sprint abgeschlossen`) auf GitHub.
#
# > **Verbesserungshinweis:** Ein gut gepflegtes GitHub‑Portfolio ist ein starkes Argument in Bewerbungsgesprächen.
#
# ---
#
# ## Block 3 (12:40 – 14:10): SPR – Reflexion des gesamten Sprints
#
# **Aufgabe:** Verfassen Sie einen abschließenden Reflexionsbericht (2‑3 Seiten) mit dem Titel: „Rückblick auf den 17‑Wochen‑Sprint: Mathematik, Data Science und AI Act“. Gehen Sie ein auf:
# - Die wichtigsten Lernerfolge (fachlich und sprachlich)
# - Herausforderungen und wie Sie sie überwunden haben
# - Praktische Anwendbarkeit des Gelernten für Master und Beruf
# - Persönliche Entwicklung (Disziplin, Zeitmanagement)
#
# Speichern Sie den Bericht als `110_abschlussreflexion_sprint.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Letzte Übung zur Grammatik
#
# **Aufgabe:** Nehmen Sie Ihren Reflexionsbericht und überarbeiten Sie ihn, indem Sie alle gelernten Grammatikstrukturen an mindestens einer Stelle anwenden (Nominalisierungen, Partizipialattribute, Relativsätze, Adverbialsätze, Passiv, Passiv‑Ersatzformen, Infinitivkonstruktionen, Nomen‑Verb‑Gefüge). Markieren Sie die verwendeten Strukturen farbig oder in Kommentaren.
#
# Speichern Sie die überarbeitete Version als `111_abschlussreflexion_grammatik.md` in Track_C.
