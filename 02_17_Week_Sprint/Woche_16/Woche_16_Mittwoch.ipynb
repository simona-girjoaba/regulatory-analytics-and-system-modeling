# %% [markdown]
# # Woche 16 – Mittwoch: Wiederholung FL, XAI, Kryptographie, Differential Privacy
#
# ## Block 1 (06:00 – 08:45): Federated Learning & Explainable AI
#
# **Aufgabe 1:** Erklären Sie den Unterschied zwischen horizontalem und vertikalem Federated Learning.
#
# **Aufgabe 2:** Skizzieren Sie den FedAvg‑Algorithmus (McMahan et al.).
#
# **Aufgabe 3:** Was ist der Unterschied zwischen SHAP und LIME? Nennen Sie Vor‑ und Nachteile.
#
# **Aufgabe 4:** Wie können SHAP‑Werte zur Erfüllung von Art. 50 beitragen?
#
# ---
#
# ## Block 2 (09:30 – 11:40): Kryptographie & Differential Privacy
#
# **Aufgabe 1:** Erklären Sie den Unterschied zwischen symmetrischer und asymmetrischer Verschlüsselung. Geben Sie je ein Beispiel (Fernet, RSA).
#
# **Aufgabe 2:** Was ist der Laplace‑Mechanismus? Wie hängen $\varepsilon$ und die Rauschskala zusammen?
#
# **Aufgabe 3:** Schreiben Sie ein kurzes Python‑Skript, das einen Laplace‑Mechanismus für eine Summe implementiert.
#
# > **Verbesserungshinweis:** Nutzen Sie Ihre Notebooks aus Woche 10, 11 und 14 zur Wiederholung.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Wiederholung AI Act (Transparenz, Grundrechte, Sanktionen, Art. 27, 50, 72‑73, 85‑87, 99‑101)
#
# **Aufgabe:** Beantworten Sie folgende Fragen in GOV:
# 1. Was verlangt Art. 27 (Grundrechte‑Folgenabschätzung)?
# 2. Was sind die Transparenzpflichten aus Art. 50?
# 3. Welche Pflichten ergeben sich aus Art. 72‑73 (Beobachtung, Meldung von Vorfällen)?
# 4. Welche Rechtsbehelfe und Beschwerderechte gibt es (Art. 85‑87)?
# 5. Wie hoch sind die maximalen Geldbußen bei Verstößen (Art. 99)?
#
# Speichern Sie Ihre Antworten als `105_wiederholung_ai_act_vertiefung.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Wiederholung Grammatik (Infinitivkonstruktionen, Nomen‑Verb‑Gefüge)
#
# **Aufgabe:** Verfassen Sie einen Aufsatz (1 Seite) über die Bedeutung von Differential Privacy für den Datenschutz im Finanzsektor. Verwenden Sie ausschließlich:
# - Infinitivkonstruktionen („um … zu“, „ohne … zu“, „(an)statt … zu“)
# - Nomen‑Verb‑Gefüge
#
# Speichern Sie als `106_grammatik_wiederholung_3.md` in Track_C.
