# %% [markdown]
# # Woche 16 – Samstag: Leichte Wiederholung & Abschluss
#
# 1. **Mathematik:** Wiederholen Sie die zentralen Formeln der SVD, PCA, Entropie, VaR, ES.
# 2. **Python:** Führen Sie einmal alle Haupt‑Notebooks (PCA, Autoencoder, SHAP, FL, DP) aus, um sicherzustellen, dass sie fehlerfrei laufen.
# 3. **Governance:** Lesen Sie Ihr finales Audit noch einmal und stellen Sie sicher, dass Sie es bei Bedarf einem Vorgesetzten oder einer Aufsichtsbehörde vorlegen könnten.
# 4. **Bewerbung:** Überprüfen Sie, ob alle Unterlagen für uni‑assist bereitliegen und die Frist eingehalten wird.
# 5. **Sprache:** Bilden Sie je 10 Sätze mit den wichtigsten Grammatikstrukturen (Nominalisierung, Passiv, Relativsatz, Adverbialsatz, Infinitivkonstruktion).
# 6. **Deutsch (Hueber):** Wiederholen Sie die Kapitel, in denen Sie noch unsicher sind.
#
# **Abschlussgedanke:** Notieren Sie in SPR einen kurzen Satz, wie Sie sich nach Abschluss des Sprints fühlen und was Ihr nächster Schritt ist.
#
# ---
# **Sonntag:** komplett lernfrei – Sie haben den Sprint abgeschlossen! 🎉
