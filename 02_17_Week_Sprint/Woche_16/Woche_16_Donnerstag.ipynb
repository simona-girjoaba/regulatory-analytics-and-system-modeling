# %% [markdown]
# # Woche 16 – Donnerstag: Finalisierung des Konformitäts‑Audits
#
# ## Block 1 (06:00 – 08:45): Audit – Vollständige Durchsicht
#
# **Aufgabe:** Nehmen Sie Ihr vollständiges Konformitäts‑Audit aus Woche 15 (Datei `99_konformitaetsaudit_aml_system_final.md`) und gehen Sie es Punkt für Punkt durch. Prüfen Sie:
# - Sind alle relevanten AI Act‑Artikel abgedeckt?
# - Sind die technischen Beschreibungen präzise und nachvollziehbar?
# - Sind die Risikobewertungen und Minderungsmaßnahmen angemessen?
# - Ist die Konformitätserklärung vollständig?
#
# Fügen Sie fehlende Inhalte hinzu und korrigieren Sie Unstimmigkeiten. Speichern Sie die finale Version als `107_konformitaetsaudit_final.md` in Track_C.
#
# ---
#
# ## Block 2 (09:30 – 11:40): Audit – Formatierung und Lesbarkeit
#
# **Aufgabe:** Überarbeiten Sie das Audit sprachlich und formatieren Sie es für die Abgabe:
# - Verwenden Sie Überschriften, Absätze und Aufzählungen.
# - Achten Sie auf einheitliche Schriftart und Zeilenabstand (z. B. 12pt, 1,5 Zeilen).
# - Fügen Sie ein Deckblatt hinzu (Titel, Datum, Verfasser, fiktive Bank).
# - Erstellen Sie ein Inhaltsverzeichnis.
#
# Exportieren Sie das Audit als PDF (z. B. über Markdown‑Konverter oder direkt aus Jupyter mit `nbconvert`). Speichern Sie die PDF als `Konformitaetsaudit_AML_System.pdf` in Track_C.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Letzte offene Fragen zum AI Act
#
# **Aufgabe:** Gehen Sie alle Ihre GOV‑Notizen der letzten Wochen durch. Notieren Sie alle verbleibenden Unklarheiten (z. B. zur Abgrenzung von Art. 5 und Art. 6, zu Ausnahmen von Art. 50). Recherchieren Sie die Antworten in der EU‑Verordnung oder in offiziellen Leitlinien. Falls nichts zu klären bleibt, notieren Sie dies als „keine offenen Fragen“.
#
# Speichern Sie Ihre Notizen als `108_ai_act_letzte_fragen.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Letzte sprachliche Überarbeitung des Audits
#
# **Aufgabe:** Lesen Sie Ihr Audit noch einmal speziell unter sprachlichen Gesichtspunkten:
# - Ersetzen Sie umgangssprachliche Wendungen durch formelle Ausdrücke.
# - Wandeln Sie zu lange Schachtelsätze in kürzere Sätze um.
# - Achten Sie auf korrekte Zeichensetzung und Groß‑/Kleinschreibung.
# - Prüfen Sie die Verwendung von Nominalisierungen und Passivkonstruktionen.
#
# Speichern Sie die endgültige Version als `109_konformitaetsaudit_sprachlich_final.md` (falls Sie eine reine Textversion behalten möchten) und überschreiben Sie die PDF aus Block 2 mit der finalen Fassung.
