# %% [markdown]
# # Woche 18 – Samstag: Leichte Wiederholung Text Mining
#
# 1. Wiederholen Sie die Konzepte: TF‑IDF, Naive Bayes, Sentimentanalyse.
# 2. Laden Sie einen öffentlichen Textdatensatz (z. B. Nachrichten aus `sklearn.datasets.fetch_20newsgroups`) und wenden Sie die Text‑Mining‑Pipeline an.
# 3. Lesen Sie einen Fachartikel zu „NLP for AML“ (z. B. auf arXiv) und notieren Sie die wichtigsten Erkenntnisse in GOV.
# 4. Bilden Sie 10 Sätze mit Passiv‑Ersatzformen zum Thema „Text Mining im Finanzsektor“.
# 5. Reflektieren Sie in SPR: Welchen Mehrwert bietet Text Mining für Ihr AML‑Portfolio?
#
# ---
# **Sonntag:** frei.
