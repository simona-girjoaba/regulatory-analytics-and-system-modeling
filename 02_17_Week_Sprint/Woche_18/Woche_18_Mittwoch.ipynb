# %% [markdown]
# # Woche 18 – Mittwoch: Textklassifikation (Spam vs. Ham) für AML
#
# ## Block 1 (06:00 – 08:45): Textklassifikation mit Naive Bayes
#
# **Lernziel:** Sie klassifizieren Nachrichten als „verdächtig“ oder „normal“.

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

messages = [
    "Regular salary payment",
    "Urgent transfer to high-risk jurisdiction",
    "Monthly rent payment",
    "Structuring detected: multiple small transfers to same account",
    "Invoice payment to known supplier"
]
labels = [0, 1, 0, 1, 0]  # 0 = normal, 1 = verdächtig

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(messages)
X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.3, random_state=42)
clf = MultinomialNB()
clf.fit(X_train, y_train)
print("Accuracy:", clf.score(X_test, y_test))

# %% [markdown]
# > **Verbesserungshinweis:** In der Praxis benötigen Sie einen großen, gelabelten Datensatz. Die Genauigkeit hängt stark von der Qualität der Daten ab.
#
# ---
#
# ## Block 2 (09:30 – 11:40): Evaluation mit Precision/Recall
#
# **Aufgabe:** Berechnen Sie Präzision und Recall für den Klassifikator.

# %%
from sklearn.metrics import precision_score, recall_score
y_pred = clf.predict(X_test)
print(f"Precision: {precision_score(y_test, y_pred):.2f}")
print(f"Recall: {recall_score(y_test, y_pred):.2f}")

# %% [markdown]
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Transparenzpflichten für Text‑Mining (Art. 50)
#
# **Aufgabe (GOV):** Erstellen Sie eine Checkliste, wie Sie sicherstellen, dass Ihr Text‑Klassifikator die Transparenzpflichten erfüllt (Erklärbarkeit der Entscheidungen, Offenlegung gegenüber Kunden).
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Relativsätze in technischen Dokumentationen
#
# **Übung:** Schreiben Sie einen kurzen Absatz (5 Sätze) über die Funktionsweise des Naive‑Bayes‑Klassifikators, wobei Sie mindestens 5 Relativsätze verwenden. Speichern Sie als `text_klassifikation_relativsaetze.md` in Track_C.
