# %% [markdown]
# # Woche 18 – Freitag: Abschluss Text Mining & Ausblick auf Netzwerkanalyse
#
# ## Block 1 (06:00 – 08:45): Zusammenfassung Text Mining
#
# **Aufgabe:** Erstellen Sie eine Mindmap in STEM, die die folgenden Konzepte verbindet: Tokenisierung, Stoppwörter, Stemming, TF‑IDF, Sentimentanalyse, Keyword‑Extraktion, Naive‑Bayes‑Klassifikation.
#
# ---
#
# ## Block 2 (09:30 – 11:40): Python – Pipeline für Text Mining in AML
#
# **Aufgabe:** Schreiben Sie eine Funktion `analyze_transaction_text(text)`, die eine Nachricht nimmt und folgende Werte zurückgibt:
# - Sentiment (polarity)
# - Top 3 Keywords
# - Klassifikation (verdächtig/normal)
#
# Testen Sie sie mit mehreren Beispielen.

# %%
def analyze_transaction_text(text):
    # Implementieren Sie hier die Pipeline
    # 1. Sentiment mit TextBlob
    # 2. Keywords mit RAKE
    # 3. Klassifikation mit Naive Bayes (trainiert auf den obigen Daten)
    pass

# Beispiel
# print(analyze_transaction_text("Urgent payment to offshore account"))

# %% [markdown]
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Abschluss Text Mining & AI Act
#
# **Aufgabe:** Beantworten Sie in GOV: Welche zusätzlichen Risiken entstehen durch den Einsatz von Text Mining im AML‑Bereich (z. B. Diskriminierung durch Sentimentanalyse)? Wie können diese Risiken gemindert werden?
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Abschluss Text Mining – Grammatikmix
#
# Schreiben Sie einen Aufsatz (1 Seite) über die Bedeutung von Text Mining für die Geldwäschebekämpfung. Verwenden Sie alle gelernten Grammatikstrukturen (Nominalisierungen, Partizipialattribute, Relativsätze, Adverbialsätze, Passiv, Passiv‑Ersatzformen, Infinitivkonstruktionen, Nomen‑Verb‑Gefüge). Speichern Sie als `text_mining_grammatik_mix.md` in Track_C.
