# %% [markdown]
# # Woche 18 – Donnerstag: Wiederholung Text Mining & Anwendung auf AML
#
# ## Block 1 (06:00 – 08:45): Theoretische Wiederholung
#
# **Aufgaben:**
# 1. Was ist der Unterschied zwischen Stemming und Lemmatisierung?
# 2. Wozu dient TF‑IDF?
# 3. Welche Metrik ist bei unausgeglichenen Klassen besser geeignet – Accuracy oder F1‑Score?
#
# ---
#
# ## Block 2 (09:30 – 11:40): Praktische Anwendung – Analyse einer echten SWIFT‑Nachricht
#
# **Aufgabe:** Verwenden Sie die gelernten Methoden, um eine fiktive SWIFT‑Nachricht zu analysieren (Text selbst erstellen). Extrahieren Sie Keywords, berechnen Sie das Sentiment und klassifizieren Sie sie als verdächtig/normal.

# %%
# Beispiel: Eigene Nachricht
swift_message = "Urgent: Transfer 250000 EUR to account 12345678 in Panama. Please process immediately."
# Wenden Sie hier Tokenisierung, TF‑IDF und Sentiment an.
print("Analyse Ihrer Nachricht:")

# %% [markdown]
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Fallstudie: Text Mining für Compliance
#
# **Aufgabe:** Schreiben Sie einen kurzen Aktionsplan (1 Seite), wie eine Bank Text Mining in ihre AML‑Pipeline integrieren könnte. Gehen Sie auf Datenquellen, rechtliche Grenzen (DSGVO) und technische Umsetzung ein. Speichern Sie als `text_mining_aktionsplan.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Adverbialsätze in Compliance‑Dokumenten
#
# **Übung:** Bilden Sie 10 Sätze mit adverbialen Nebensätzen (kausal, temporal, konditional) zum Thema „Einführung von Text Mining in der Bank“. Beispiel: „Nachdem die Keyword‑Extraktion durchgeführt wurde, werden verdächtige Nachrichten priorisiert.“
