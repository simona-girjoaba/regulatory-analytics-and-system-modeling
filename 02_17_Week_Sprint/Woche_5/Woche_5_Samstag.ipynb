# %% [markdown]
# # Woche 5 – Samstag: Wiederholung Maßtheorie & AI Act
#
# **Kein neuer Stoff.**
#
# 1. **Mathematik:** Wiederholen Sie die Definitionen des äußeren Maßes, des Lebesgue‑Maßes und der messbaren Funktion. Erstellen Sie eine Mindmap in STEM.
# 2. **Governance:** Lesen Sie Ihr technisches Dokumentations‑Template. Überlegen Sie, welche Punkte für Ihren Autoencoder besonders wichtig sind.
# 3. **Sprache:** Bilden Sie 10 Sätze mit schwierigen Präpositionen („trotz“, „aufgrund“, „hinsichtlich“, „in Bezug auf“) zum Thema AI Act.
# 4. **Deutsch (Hueber):** Lektion zu Präpositionen wiederholen (Wortschatz & Grammatik C2).
#
# **Reflexion:** Notieren Sie in SPR, was Ihnen an der Maßtheorie am schwersten fiel. Planen Sie eine zusätzliche Lerneinheit (z. B. am Samstag nächste Woche) zur Vertiefung.
#
# ---
# **Sonntag:** komplett lernfrei.
