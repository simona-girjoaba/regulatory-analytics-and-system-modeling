# %% [markdown]
# # Woche 5 – Donnerstag: Wiederholung äußeres Maß, Lebesgue‑Maß, messbare Funktionen
#
# ## Block 1 (06:00 – 08:45): Übungen zur Maßtheorie
#
# **Aufgabe 1:** Zeigen Sie, dass das äußere Maß translationsinvariant ist: $\lambda^*(A + c) = \lambda^*(A)$ für $c \in \mathbb{R}^n$.
#
# **Aufgabe 2:** Beweisen Sie, dass jede abzählbare Menge $\lambda$‑messbar ist und Maß Null hat.
#
# **Aufgabe 3:** Ist die Dirichlet‑Funktion ($f(x)=1$ für rationale $x$, sonst $0$) messbar? (Ja, weil sie charakteristische Funktion von $\mathbb{Q}$ ist – $\mathbb{Q}$ ist messbar mit Maß Null.)
#
# > **Verbesserungshinweis:** Falls Sie bei den Beweisen unsicher sind, lesen Sie Elstrodt Kap. 3.2‑3.3 (S. 60‑80).
#
# ---
#
# ## Block 2 (09:30 – 11:40): Autoencoder – Training vorbereiten
#
# **Aufgabe:** Schreiben Sie eine Trainingsschleife für Ihren Autoencoder (Dummy‑Daten). Verwenden Sie `torch.optim.Adam` und `MSELoss`.
#
# ```python
# model = SimpleAE()  # von gestern
# optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
# criterion = nn.MSELoss()
# data = torch.randn(100, 5)  # 100 Beispiele, 5 Merkmale
# for epoch in range(100):
#     out = model(data)
#     loss = criterion(out, data)
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()
#     if epoch % 20 == 0:
#         print(f'Epoch {epoch}, Loss: {loss.item():.4f}')
# ```
#
# > **Verbesserungshinweis:** Der Loss sollte sinken. Falls nicht, erhöhen Sie die Lernrate oder die Anzahl der Epochen.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Template für technische Dokumentation finalisieren
#
# Nehmen Sie Ihr Template von Montag und ergänzen Sie die Abschnitte zu Art. 12‑15 (Logging, Cybersicherheit, automatische Überwachung, Metriken). Speichern Sie als `20_technische_dokumentation_template_final.md` in Track_C.
#
# > **Verbesserungshinweis:** Ein vollständiges Template ist später (Woche 13) Grundlage für das Konformitäts‑Audit.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Wiederholung Präpositionen & Fachtexte
#
# Schreiben Sie einen kurzen Aufsatz (1 Seite) mit dem Titel: „Die Bedeutung der Maßtheorie für die Risikomodellierung in Banken“. Verwenden Sie die gelernten Präpositionen korrekt. Speichern Sie als `21_aufsatz_masstheorie_banken.md` in Track_C.
