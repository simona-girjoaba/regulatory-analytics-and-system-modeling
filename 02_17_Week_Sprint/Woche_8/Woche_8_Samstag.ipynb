# %% [markdown]
# # Woche 8 – Samstag: Leichte Wiederholung & Reflexion
#
# 1. **Mathematik:** Wiederholen Sie die Konvergenzsätze und die Definition der Lp‑Räume – am besten mit Karteikarten.
# 2. **Zeitreihen:** Laden Sie einen öffentlichen Zeitreihendatensatz (z. B. monatliche Arbeitslosenzahlen von destatis.de) und führen Sie eine kurze ARIMA‑Analyse durch.
# 3. **Risikomaße:** Berechnen Sie VaR und ES für einen selbst erzeugten Datensatz mit einer nicht‑normalen Verteilung (z. B. t‑Verteilung mit wenigen Freiheitsgraden).
# 4. **Governance:** Lesen Sie Ihren Konformitätsplan von Donnerstag noch einmal und überlegen Sie, ob Sie alle Pflichten aus Art. 16‑21 abgedeckt haben.
# 5. **Sprache:** Bilden Sie 10 Sätze mit Zustandspassiv („ist … worden“, „ist …“) zu den Themen „Modelltraining“ und „Konformitätsbewertung“.
# 6. **Deutsch (Hueber):** Lektion zum Passiv (Vorgang vs. Zustand) wiederholen.
#
# **Reflexion:** Schreiben Sie in SPR einen kurzen Absatz darüber, welche Themen aus den Wochen 5‑7 Ihnen noch Schwierigkeiten bereiten und wie Sie diese in den nächsten Wochen adressieren wollen.
#
# ---
# **Sonntag:** komplett lernfrei.
