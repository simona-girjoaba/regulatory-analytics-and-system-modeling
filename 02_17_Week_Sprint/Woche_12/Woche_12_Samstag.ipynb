# %% [markdown]
# # Woche 12 – Samstag: Leichte Wiederholung & Reflexion
#
# 1. **Mathematik/Risikomaße:** Wiederholen Sie die Definition von VaR, ES und die Kohärenz-Eigenschaften.
# 2. **Federated Learning:** Zeichnen Sie ein Diagramm des FedAvg‑Algorithmus auf Papier.
# 3. **XAI:** Erklären Sie einer fiktiven Person (z. B. einem Kollegen) den Unterschied zwischen SHAP und LIME.
# 4. **Governance:** Lesen Sie Ihre Grundrechte‑Folgenabschätzung aus Woche 10 und überlegen Sie, ob Sie Art. 50 ausreichend berücksichtigt haben.
# 5. **Sprache:** Bilden Sie 10 Sätze im Zustandspassiv zu den Themen „Risikomessung“ und „Modelltransparenz“.
# 6. **Deutsch (Hueber):** Lektion zu Passiv‑Ersatzformen wiederholen (Wortschatz & Grammatik C2).
#
# **Reflexion:** Notieren Sie in SPR, welche Themen aus den Wochen 9‑11 Ihnen noch unsicher sind und wie Sie diese in den nächsten Wochen adressieren wollen.
#
# ---
# **Sonntag:** komplett lernfrei.
