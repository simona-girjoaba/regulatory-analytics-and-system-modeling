# %% [markdown]
# # Woche 12 – Freitag: Abschluss der Pufferwoche & Vorbereitung auf Woche 13 (Zeitreihen II)
#
# ## Block 1 (06:00 – 08:45): Letzte Wiederholung
#
# Erstellen Sie eine **Mindmap** in STEM, die alle Themen der Wochen 9‑11 miteinander verbindet:
# - Risikomaße (VaR, ES, Copulas)
# - Autoencoder (Anomalieerkennung)
# - Federated Learning (horizontal, vertikal, FedAvg)
# - Explainable AI (SHAP, LIME)
# - AI Act Art. 50 (Transparenzpflichten)
# - Grundrechte‑Folgenabschätzung (Art. 27)
#
# > **Verbesserungshinweis:** Die Mindmap hilft Ihnen, die Querverbindungen zu sehen – z. B. dass XAI zur Erfüllung von Art. 50 beiträgt.
#
# ---
#
# ## Block 2 (09:30 – 11:40): Python – Abschlussübung: All-in-One
#
# **Aufgabe:** Kombinieren Sie die Methoden: Trainieren Sie einen Autoencoder auf Ihren AML‑Daten, berechnen Sie die SHAP‑Werte für eine Anomalie (verwenden Sie `KernelExplainer` oder `DeepExplainer`) und interpretieren Sie das Ergebnis.

# %%
# Beispielskizze – erfordert vollständigen Code aus Woche 9 und Woche 11
# Hier nur eine Struktur, die Sie anpassen können:
# 1. Autoencoder laden
# 2. SHAP KernelExplainer mit Hintergrunddaten
# 3. SHAP-Werte für eine auffällige Transaktion berechnen
# 4. Wasserfall Plot erstellen
print("Diese Zelle ist eine Vorlage – bitte Code aus Woche 9 und 11 einfügen.")

# %% [markdown]
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Offene Fragen klären
#
# Gehen Sie alle Ihre Notizen aus Woche 9‑11 durch. Notieren Sie alle verbleibenden Unklarheiten in GOV. Versuchen Sie, sie mit Hilfe der Primärquellen (EU AI Act, McNeil/Frey/Embrechts, McMahan et al., SHAP‑Dokumentation) zu klären.
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Ausblick auf Woche 13
#
# In Woche 13 behandeln wir **Zeitreihenanalyse II (SARIMA, Prognose)**. Lesen Sie bereits jetzt die Kapitel zu SARIMA in Hyndman/Athanasopoulos (Kap. 8‑9) und notieren Sie die wichtigsten Begriffe in SPR.
#
# **Grammatikvorschau:** Wir werden Nomen‑Verb‑Gefüge (Kap. 1.7) wiederholen und vertiefen.
