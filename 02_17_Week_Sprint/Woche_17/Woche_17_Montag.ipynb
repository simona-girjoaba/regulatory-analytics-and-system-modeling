# %% [markdown]
# # Woche 17 – Montag: Bewerbungsunterlagen finalisieren & Audit‑Endkontrolle
#
# ## Block 1 (06:00 – 08:45): Bewerbungsunterlagen für uni‑assist
#
# **Aufgabe:** Stellen Sie sicher, dass alle folgenden Dokumente vollständig, korrekt und beglaubigt (falls erforderlich) vorliegen:
# - Motivationsschreiben (1‑2 Seiten, auf Deutsch, C2‑Niveau)
# - Lebenslauf (tabellarisch, aktuell, mit Link zu Ihrem GitHub‑Portfolio)
# - Bachelorzeugnis (beglaubigte Kopie, ggf. amtliche Übersetzung)
# - Deutsch‑Sprachnachweis (mindestens B2, für die spätere Einschreibung DSH‑2 oder gleichwertig)
# - Passkopie
# - ggf. weitere geforderte Dokumente (siehe THM‑Webseite und uni‑assist‑Portal)
#
# **Speichern Sie alle Dokumente in einem separaten Ordner `Bewerbung_THM` (außerhalb des Sprint‑Repositories).**
#
# > **Verbesserungshinweis:** Die Frist für internationale Bewerber über uni‑assist endet am **15. Juli**. Reichen Sie die Unterlagen **mindestens zwei Wochen vorher** ein, da die Bearbeitung mehrere Wochen dauern kann.
#
# ---
#
# ## Block 2 (09:30 – 11:40): Konformitäts‑Audit – letzte inhaltliche Prüfung
#
# **Aufgabe:** Öffnen Sie Ihr finales Audit (`107_konformitaetsaudit_final.md` oder `Konformitaetsaudit_AML_System.pdf`). Prüfen Sie erneut:
# - Sind alle AI Act‑Artikel von Art. 5 bis Art. 101 (soweit relevant) adressiert?
# - Sind die technischen Beschreibungen Ihres Autoencoders präzise und nachvollziehbar?
# - Sind die Risikobewertungen und Minderungsmaßnahmen angemessen und konkret?
# - Ist die Konformitätserklärung (Art. 48) unterschrieben (Platzhalter genügt)?
# - Sind alle Anhänge (technische Dokumentation, Logging‑Konzept, XAI‑Berichte) vorhanden?
#
# Nehmen Sie letzte Korrekturen vor und speichern Sie die finale Version als `112_konformitaetsaudit_ende_gueltig.pdf` (als PDF) in Track_C.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Letzte Wiederholung AI Act (Sanktionen, Inkrafttreten)
#
# **Aufgabe:** Beantworten Sie in GOV abschließend:
# 1. Ab wann gilt der AI Act vollständig? (2. August 2026)
# 2. Welche Sanktionen drohen bei Verstößen gegen Art. 5? (bis zu 30 Mio. € oder 6% des weltweiten Jahresumsatzes)
# 3. Welche Übergangsfristen gibt es für bereits in Verkehr gebrachte Systeme? (Art. 111)
# 4. Was ist der „Code of Practice“ für GPAI‑Modelle? (Art. 56)
#
# Speichern Sie Ihre Antworten als `113_ai_act_letzte_fakten.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Feinschliff des Motivationsschreibens
#
# **Aufgabe:** Überarbeiten Sie Ihr Motivationsschreiben unter Verwendung aller gelernten Grammatikstrukturen:
# - Nominalisierungen
# - Partizipialattribute
# - Relativsätze
# - Adverbialsätze (kausal, temporal, konditional, konzessiv)
# - Vorgangs‑ und Zustandspassiv
# - Passiv‑Ersatzformen
# - Infinitivkonstruktionen
# - Nomen‑Verb‑Gefüge
#
# Lassen Sie das Schreiben von einer KI (oder einer Person mit C2‑Niveau) gegenlesen. Speichern Sie die finale Version als `Motivationsschreiben_THM_final.pdf` im Bewerbungsordner.
