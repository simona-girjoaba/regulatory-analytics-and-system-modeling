# %% [markdown]
# # Woche 17 – Donnerstag: Bewerbung abschließen & Portfolio veröffentlichen
#
# ## Block 1 (06:00 – 08:45): uni‑assist – Bewerbung einreichen
#
# **Aufgabe:** Gehen Sie auf das uni‑assist‑Portal, füllen Sie den Antrag für den Masterstudiengang „Mathematik für Nachhaltigkeit, Wirtschaft und Data Science“ an der THM Friedberg aus. Laden Sie alle erforderlichen Dokumente hoch. Zahlen Sie die Bearbeitungsgebühr (falls nicht bereits geschehen).
#
# **Dokumentieren Sie den Eingang** (Bestätigungs-E-Mail speichern).
#
# > **Verbesserungshinweis:** Die Bearbeitung durch uni‑assist kann 4‑6 Wochen dauern. Je früher Sie einreichen, desto besser.
#
# ---
#
# ## Block 2 (09:30 – 11:40): LinkedIn‑Profil aktualisieren
#
# **Aufgabe:** Aktualisieren Sie Ihr LinkedIn‑Profil:
# - Fügen Sie den 17‑Wochen‑Sprint als Projekt hinzu.
# - Verlinken Sie Ihr GitHub‑Repository.
# - Betonen Sie die erworbenen Fähigkeiten: Mathematik (Maßtheorie, Zeitreihen, Risikomaße), Python (Autoencoder, FL, XAI, DP), EU AI Act, akademisches Deutsch (C2).
# - Verbinden Sie sich mit relevanten Gruppen (AML, Data Science, Privacy Engineering).
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Letzte Reflexion zum AI Act
#
# **Aufgabe:** Schreiben Sie einen kurzen Aufsatz (1 Seite) mit dem Titel: „Der EU AI Act aus Sicht eines Privacy Engineers – eine Bewertung nach 17 Wochen Vorbereitung“. Speichern Sie als `118_ai_act_bewertung.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Abschließende Selbstbewertung
#
# **Aufgabe:** Verfassen Sie eine Selbstbewertung (1 Seite) Ihres Sprachniveaus. Gehen Sie ein auf:
# - Welche Grammatikthemen beherrschen Sie sicher?
# - Welche Themen möchten Sie noch vertiefen?
# - Wie hat der Sprint Ihr akademisches Deutsch verbessert?
#
# Speichern Sie als `119_selbstbewertung_deutsch.md` in Track_C.
