# %% [markdown]
# # Woche 17 – Freitag: Abschluss des Sprints & Ausblick
#
# ## Block 1 (06:00 – 08:45): Finale Wiederholung der wichtigsten Konzepte
#
# **Aufgabe:** Erstellen Sie eine **einseitige Spickzettel** (Cheat Sheet) in STEM mit den wichtigsten Formeln und Definitionen:
# - Vektorraumaxiome (kurz)
# - Normen ($\ell_1,\ell_2,\ell_\infty$)
# - SVD ($A = U\Sigma V^T$)
# - VaR und ES
# - Entropie $H(X) = -\sum p_i \log p_i$
# - RSA: $c = m^e \mod n$, $m = c^d \mod n$
# - Laplace‑Mechanismus: $f(x) + \text{Laplace}(\text{scale} = \Delta f / \varepsilon)$
#
# ---
#
# ## Block 2 (09:30 – 11:40): Abschluss des GitHub‑Portfolios
#
# **Aufgabe:** Führen Sie einen letzten `git push` durch. Erstellen Sie ein **Release** mit der Bezeichnung `v2.0 – 17‑Wochen‑Sprint vollständig abgeschlossen`. Fügen Sie eine kurze Beschreibung hinzu, was der Sprint umfasst.
#
# ---
#
# ## Block 3 (12:40 – 14:10): Ausblick auf den Masterstudiengang
#
# **Aufgabe:** Schauen Sie sich das Modulhandbuch der THM an (Sie haben es bereits). Notieren Sie, welche Wahlpflichtmodule Sie belegen möchten (z. B. MAM362 Data Science I, MAM364 Approximationstheorie mit neuronalen Netzen, MAM329 Nachhaltiges Risikomanagement, MAM389 Codierungstheorie und Kryptographie).
#
# Speichern Sie Ihre Wahl als `120_wahlpflichtmodule_thm.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:00): Abschlussreflexion & Danksagung
#
# **Aufgabe:** Schreiben Sie einen abschließenden Eintrag in Ihr SPR‑Notebook mit dem Titel: „Was mir der 17‑Wochen‑Sprint gebracht hat“. Bedanken Sie sich bei sich selbst für die Disziplin. Speichern Sie eine Kopie als `121_abschluss_danksagung.md` in Track_C.
#
# **Herzlichen Glückwunsch! Sie haben den 17‑Wochen‑Sprint erfolgreich abgeschlossen.** 🎉
