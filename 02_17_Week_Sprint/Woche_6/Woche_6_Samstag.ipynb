# %% [markdown]
# # Woche 6 – Samstag: Wiederholung Integration, VaR, Passiv
#
# 1. **Mathematik:** Wiederholen Sie die Konvergenzsätze (monotone und dominierte Konvergenz) und die Definition der Lp‑Räume. Erstellen Sie eine kurze Zusammenfassung in STEM.
# 2. **Risikomaße:** Berechnen Sie VaR und ES für einen selbst erzeugten Zufallsdatensatz (z. B. 1000 normale Zufallszahlen). Notieren Sie die Ergebnisse.
# 3. **Governance:** Lesen Sie Ihre Zusammenfassung der Art. 16‑21 und ergänzen Sie offene Fragen.
# 4. **Sprache:** Bilden Sie 10 Sätze im Passiv mit Modalverben zum Thema Risikomanagement.
# 5. **Deutsch (Hueber):** Lektion zum Passiv wiederholen (Wortschatz & Grammatik C2).
#
# **Reflexion:** Notieren Sie in SPR, wie sich das Verständnis von Risikomaßen auf Ihre Sicht auf AML‑Systeme auswirkt.
#
# ---
# **Sonntag:** komplett lernfrei.
