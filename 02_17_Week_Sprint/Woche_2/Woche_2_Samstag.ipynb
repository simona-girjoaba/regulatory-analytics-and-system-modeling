# %% [markdown]
# # Woche 2 – Samstag: Wiederholung
#
# **Mathematik:**
# - Wiederholen Sie die Regeln der Matrizenmultiplikation (Dimensionsprüfung).
# - Berechnen Sie die Inverse von $\begin{pmatrix}1&3\\2&7\end{pmatrix}$ per Hand und mit Python.
# - Lösen Sie ein lineares Gleichungssystem mit $2\times2$‑Matrizen.
#
# **Governance:**
# - Lesen Sie Ihre Stellungnahmen zu Art. 5(1)(a‑d) noch einmal und überprüfen Sie die Argumente.
# - Hören Sie einen Podcast zu „Verbotene KI‑Praktiken im Finanzsektor“.
#
# **Sprache:**
# - Bilden Sie 5 Sätze mit Partizipialattributen aus dem Kontext der Matrixinvertierung (z. B. „Die durch Gauß‑Elimination invertierte Matrix …“).
#
# **Deutsch (Hueber):** Lektion zu Partizipialattributen (Wortschatz & Grammatik C2) wiederholen.
#
# ---
# **Sonntag:** komplett lernfrei.
