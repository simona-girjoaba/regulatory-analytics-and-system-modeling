# %% [markdown]
# # Woche 4 – Samstag: Leichte Wiederholung & Reflexion
#
# **Kein neuer Stoff. Nutzen Sie den Tag für leichte Aktivitäten.**
#
# 1. **Mathematik:** Wiederholen Sie die Definitionen der Normen, Metriken, SVD und PCA – am besten mit Karteikarten (physisch oder in STEM).
# 2. **Governance:** Hören Sie einen Podcast zum AI Act (z. B. „Hochrisiko‑KI im Finanzsektor“). Notieren Sie in GOV zwei neue Erkenntnisse.
# 3. **Sprache:** Lesen Sie Ihre Zusammenfassung von gestern noch einmal und korrigieren Sie stilistische Schwächen (z. B. übermäßige Nominalisierung – manchmal ist ein Verb besser).
# 4. **Deutsch (Hueber):** Wiederholen Sie die Lektionen zu Nominalisierungen, Partizipialattributen und Relativsätzen (je 15 Minuten).
#
# **Reflexionsfrage (schriftlich in SPR):**
# *Welche der ersten drei Wochen fiel Ihnen am schwersten? Welche konkrete Maßnahme werden Sie ergreifen, um dieses Defizit auszugleichen?*
#
# ---
# **Sonntag:** komplett lernfrei.
