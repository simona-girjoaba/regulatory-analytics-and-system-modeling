# %% [markdown]
# # Woche 1 – Samstag: Leichte Wiederholung
#
# **Ziel:** Festigung der Inhalte der Woche ohne neuen Stoff.
#
# ## Wiederholungsaufgaben
#
# ### 1. Mathematik (STEM)
# - Schreiben Sie die acht Vektorraumaxiome aus dem Gedächtnis auf.
# - Berechnen Sie die $\ell_1$, $\ell_2$ und $\ell_\infty$‑Norm für $x = (-3, 0, 4)$ per Hand und kontrollieren Sie mit Python.
# - Wiederholen Sie die Definition einer Metrik und die Beziehung zwischen Norm und Metrik.
#
# ### 2. Governance (GOV)
# - Hören Sie einen Podcast zum AI Act (z. B. „Legal AI – Der KI‑Act für Finanzinstitute“). Notieren Sie drei neue Erkenntnisse.
# - Lesen Sie Ihr Glossar (Art. 3) und prüfen Sie, ob Sie alle 10 Begriffe erklären können.
#
# ### 3. Sprache (SPR)
# - Bilden Sie 5 nominalisierte Sätze aus Ihrem Memo zur KI‑Kompetenz.
# - Überarbeiten Sie Ihren Aufsatz von Mittwoch – ersetzen Sie drei Verben durch weitere Nominalisierungen.
#
# ### 4. Deutsch (Hueber)
# - *Hueber Wortschatz & Grammatik C2* – Lektion 1 wiederholen, offene Übungen nachholen.
#
# ---
# **Sonntag:** komplett lernfrei.
