# %% [markdown]
# # Woche 9 – Samstag: Wiederholung Risikomaße, Autoencoder, Grundrechte
#
# 1. **Mathematik:** Wiederholen Sie die Definitionen von VaR, ES und die Eigenschaft der Kohärenz. Schreiben Sie die Formeln auf.
# 2. **Copulas:** Simulieren Sie eine Archimedische Copula (z. B. Clayton‑Copula) mit Python (verwenden Sie `scipy.stats` oder selbst gebaute Inverse).
# 3. **Autoencoder:** Laden Sie das beste Modell und wenden Sie es auf einen neuen synthetischen Datensatz an (mit echten Ausreißern). Berechnen Sie Precision/Recall.
# 4. **Governance:** Lesen Sie Ihre Grundrechte‑Folgenabschätzung und überlegen Sie, ob Sie alle betroffenen Grundrechte abgedeckt haben.
# 5. **Sprache:** Bilden Sie 10 Sätze im Zustandspassiv zum Thema „Risikomanagement“.
# 6. **Deutsch (Hueber):** Lektion zum Zustandspassiv wiederholen (Wortschatz & Grammatik C2).
#
# **Reflexion:** Notieren Sie in SPR, wie sich Ihr Verständnis von Risikomaßen auf die Gestaltung eines AML‑Systems auswirkt.
#
# ---
# **Sonntag:** komplett lernfrei.
