# %% [markdown]
# # Woche 9 – Freitag: Abschluss Risikomaße & Autoencoder
#
# ## Block 1 (06:00 – 08:45): Zusammenfassung der Woche
#
# **Aufgabe:** Erstellen Sie eine Mindmap in STEM, die die folgenden Konzepte verbindet:
# - VaR und ES (Kohärenz)
# - Copulas (Gauß, t)
# - Autoencoder (Training, Hyperparameter, Rekonstruktionsfehler)
# - Grundrechte‑Folgenabschätzung (Art. 27)
#
# ---
#
# ## Block 2 (09:30 – 11:40): Python – Finale Optimierung des Autoencoders
#
# **Aufgabe:** Versuchen Sie, den Autoencoder weiter zu verbessern, indem Sie zusätzliche Merkmale erzeugen (z. B. Transaktionszeit, Wochentag) – falls Ihre Daten diese Informationen enthalten. Falls nicht, erzeugen Sie synthetische zusätzliche Merkmale (z. B. `amount_quadrat`). Wiederholen Sie die Hyperparameter‑Suche und vergleichen Sie die Anomalieerkennung.

# %%
# Beispiel: zusätzliches Merkmal amount_quadrat
features['amount_quadrat'] = features['amount'] ** 2
scaler2 = StandardScaler()
X2 = torch.tensor(scaler2.fit_transform(features), dtype=torch.float32)
# Hier könnten Sie die Hyperparameter‑Suche wiederholen (Code analog zu Montag)
print('Neue Feature‑Dimension:', X2.shape[1])

# %% [markdown]
# > **Verbesserungshinweis:** Mehr Merkmale können die Erkennungsleistung verbessern, erhöhen aber auch die Gefahr von Overfitting.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Finalisierung der Grundrechte‑Folgenabschätzung
#
# Nehmen Sie Ihre ausgefüllte Folgenabschätzung von Mittwoch und überarbeiten Sie sie unter Verwendung des **Zustandspassivs**. Speichern Sie die finale Version als `48_grundrechte_folgenabschaetzung_final.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Grammatikmix
#
# Schreiben Sie einen einseitigen Aufsatz über die Bedeutung von Risikomaßen für die AML‑Überwachung. Verwenden Sie:
# - Nominalisierungen
# - Partizipialattribute
# - Relativsätze
# - Adverbialsätze
# - Vorgangs‑ und Zustandspassiv
#
# Speichern Sie als `49_grammatik_mix_risikomasse.md` in Track_C.
