# %% [markdown]
# # Woche 10 – Samstag: Wiederholung FL & Passiv‑Ersatzformen
#
# 1. **Mathematik:** Wiederholen Sie die Definition konvexer Funktionen. Zeigen Sie, dass $f(x)=x^2$ konvex ist.
# 2. **Federated Learning:** Skizzieren Sie den FedAvg‑Algorithmus auf einem Blatt Papier. Erklären Sie, warum FL datenschutzfreundlich ist.
# 3. **Python:** Erweitern Sie die FL‑Simulation von Dienstag auf drei Clients mit ungleicher Datenmenge. Gewichten Sie die Updates entsprechend.
# 4. **Governance:** Lesen Sie Ihre finale Grundrechte‑Folgenabschätzung und überlegen Sie, ob Sie alle Risiken abgedeckt haben.
# 5. **Sprache:** Bilden Sie 10 Sätze mit „sich lassen“ und „sein + zu + Infinitiv“ zum Thema „Risikobewertung von FL“.
# 6. **Deutsch (Hueber):** Lektion zu Passiv‑Ersatzformen wiederholen.
#
# **Reflexion:** Notieren Sie in SPR, welche Vorteile FL für Ihre Arbeit als Privacy Engineer bietet.
#
# ---
# **Sonntag:** komplett lernfrei.
