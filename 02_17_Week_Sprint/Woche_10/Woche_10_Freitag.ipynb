# %% [markdown]
# # Woche 10 – Freitag: Abschluss Federated Learning & Ausblick auf Explainable AI
#
# ## Block 1 (06:00 – 08:45): Zusammenfassung FL
#
# **Aufgabe:** Erstellen Sie eine Mindmap in STEM, die die folgenden Konzepte verbindet:
# - Horizontales vs. vertikales FL
# - FedAvg Algorithmus
# - Sicherheitsrisiken (Poisoning, Inference)
# - Schutzmaßnahmen (Secure Aggregation, Differential Privacy)
# - Grundrechte‑Folgenabschätzung (Art. 27)
#
# ---
#
# ## Block 2 (09:30 – 11:40): Python – Vergleich zentrales vs. FL‑Modell
#
# **Aufgabe:** Trainieren Sie ein zentrales Modell auf allen Daten (Client1 + Client2 zusammen) und vergleichen Sie die Genauigkeit mit dem FL‑Modell. (Nutzen Sie den Code von Dienstag als Grundlage.)
#
# ```python
# # Zentrales Training (vereinfacht)
# X_all = torch.cat([X1, X2], dim=0)
# # Hier müsste ein Modell trainiert werden (z. B. lineare Regression)
# # Dies ist eine Skizze – Sie können das Modell von Dienstag verwenden.
# print('Zentrales Training würde hier durchgeführt.')
# ```
#
# > **Verbesserungshinweis:** FL kann bei nicht‑IID‑Daten etwas schlechter abschneiden als zentrales Training, bietet aber Datenschutzvorteile.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Finalisierung der Grundrechte‑Folgenabschätzung
#
# Nehmen Sie Ihre Folgenabschätzung von Mittwoch und überarbeiten Sie sie unter Verwendung der Passiv‑Ersatzformen („sich lassen“, „sein + zu + Infinitiv“). Speichern Sie die finale Version als `57_fl_grundrechte_final.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Ausblick auf Woche 11 (Explainable AI) & Präsentation der Resultate
#
# **Teil A:** Lesen Sie die Einleitung zu SHAP und LIME (z. B. im XAI‑Guide 2024). Notieren Sie in SPR, was Sie über Explainable AI bereits wissen und was Sie sich erhoffen.
#
# **Teil B (neu – aus dem 12‑Wochen‑Plan):** Erstellen Sie eine **Präsentation** (`Presentation.md`) der Ergebnisse Ihrer Anomalieerkennung (aus Woche 9) im **akademischen Nomen‑Verb‑Stil**. Verwenden Sie keine vollständigen Sätze mit Verben, sondern nominalisierte Ausdrücke (z. B. „Die Identifikation von Ausreißern durch den Autoencoder“ statt „Der Autoencoder identifiziert Ausreißer“).
#
# **Inhalt der Präsentation (1 Seite):**
# - Kurze Beschreibung des Autoencoders
# - Darstellung der erkannten Anomalien (Top‑5 Transaktionen)
# - Bewertung der Methode (Stärken, Schwächen)
# - Ausblick auf Verbesserungen (z. B. durch Federated Learning)
#
# Speichern Sie die Präsentation als `58_presentation_anomalieerkennung.md` im Ordner `Track_A_Applied_Engineering_Michigan/03_Applied_Machine_Learning/`.
#
# > **Verbesserungshinweis:** Der Nomen‑Verb‑Stil (auch Nominalstil) ist typisch für wissenschaftliche Präsentationen, Abstracts und Zusammenfassungen. Er wirkt präzise und formell.
#
# **Teil C:** Wiederholen Sie alle gelernten Grammatikthemen (Nominalisierungen, Partizipialattribute, Relativsätze, Adverbialsätze, Vorgangs‑/Zustandspassiv, Passiv‑Ersatzformen).
