# %% [markdown]
# # Woche 11 – Samstag: Wiederholung XAI & Art. 50
#
# 1. **Mathematik/Algorithmen:** Wiederholen Sie die Unterschiede zwischen SHAP und LIME. Erstellen Sie eine kurze Zusammenfassung in STEM.
# 2. **Python:** Wenden Sie SHAP auf ein Modell Ihrer Wahl an (z. B. ein Decision Tree auf Ihren AML‑Daten). Dokumentieren Sie die SHAP‑Werte.
# 3. **Governance:** Lesen Sie Ihren Transparenzbericht (Woche 11 Donnerstag) und überlegen Sie, ob Sie alle Anforderungen von Art. 50 abgedeckt haben.
# 4. **Sprache:** Bilden Sie 10 Sätze im Zustandspassiv zum Thema „KI‑Transparenz“.
# 5. **Deutsch (Hueber):** Lektion zum Zustandspassiv wiederholen (Wortschatz & Grammatik C2).
#
# **Reflexion:** Notieren Sie in SPR, wie XAI zur Erfüllung von Art. 50 beitragen kann.
#
# ---
# **Sonntag:** komplett lernfrei.
