# %% [markdown]
# # Woche 14 – Samstag: Leichte Wiederholung
#
# 1. **Kryptographie:** Wiederholen Sie den Unterschied zwischen symmetrischer und asymmetrischer Verschlüsselung. Schreiben Sie die RSA‑Formeln auf.
# 2. **Differential Privacy:** Wiederholen Sie die Definition von ε‑DP und die Formel des Laplace‑Mechanismus.
# 3. **Python:** Erstellen Sie ein Skript, das eine Datei symmetrisch verschlüsselt und wieder entschlüsselt (mit `cryptography.fernet`).
# 4. **Governance:** Lesen Sie Ihre Zusammenfassung zu Art. 74‑87 und überlegen Sie, ob Ihr AML‑System den Rechtsbehelfen (Art. 86) genügt.
# 5. **Sprache:** Bilden Sie 10 Sätze mit Infinitivkonstruktionen zum Thema „Verschlüsselung und Datenschutz“.
# 6. **Deutsch (Hueber):** Lektion zu Infinitivkonstruktionen wiederholen (Wortschatz & Grammatik C2).
#
# **Reflexion:** Notieren Sie in SPR, welche kryptographischen Verfahren Sie für Ihr AML‑Portfolio einsetzen würden und warum.
#
# ---
# **Sonntag:** komplett lernfrei.
