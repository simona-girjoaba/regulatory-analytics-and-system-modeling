# %% [markdown]
# # Woche 14 – Freitag: Abschluss Kryptographie & Differential Privacy
#
# ## Block 1 (06:00 – 08:45): Wiederholung Kryptographie
#
# **Aufgabe:** Erstellen Sie eine Mindmap in STEM, die die folgenden Konzepte verbindet:
# - Symmetrische Verschlüsselung (Fernet, AES)
# - Asymmetrische Verschlüsselung (RSA, Schlüsselpaar, hybride Verschlüsselung)
# - Hashfunktionen (SHA‑256, Einwegfunktionen)
# - Anwendungen in der Praxis (HTTPS, E‑Mail, digitale Signaturen)
#
# ---
#
# ## Block 2 (09:30 – 11:40): Wiederholung Differential Privacy
#
# **Aufgabe:** Führen Sie einen ε‑Parameter‑Vergleich durch: Berechnen Sie die private Summe Ihrer AML‑Daten für verschiedene ε‑Werte (0,1, 0,5, 1,0, 2,0) und visualisieren Sie den Trade‑off zwischen Privatsphäre und Genauigkeit.

# %%
import numpy as np
import matplotlib.pyplot as plt

true_sum = np.sum(amounts)
sensitivity = amounts.max()
epsilons = [0.1, 0.5, 1.0, 2.0]

private_sums = []
for eps in epsilons:
    private_sums.append(laplace_mechanism(true_sum, sensitivity, eps))

plt.bar(range(len(epsilons)), private_sums, tick_label=[str(e) for e in epsilons])
plt.axhline(y=true_sum, color='r', linestyle='--', label='Wahrer Wert')
plt.xlabel('ε (Privatsphärenparameter)')
plt.ylabel('Private Summe')
plt.title('Einfluss von ε auf die Genauigkeit')
plt.legend()
plt.show()

# %% [markdown]
# > **Verbesserungshinweis:** Je kleiner ε, desto größer der Schutz, aber auch desto größer die Abweichung vom wahren Wert. Ein typischer Kompromiss liegt bei ε = 0,5–1,0.
#
# ---
#
# ## Block 3 (12:40 – 14:10): GOV – Abschluss Art. 74‑87
#
# Beantworten Sie folgende Fragen in GOV:
# 1. Welche Sanktionen drohen bei Verstößen gegen die Marktüberwachungspflichten? (Art. 99)
# 2. Wie können Bürger eine Beschwerde einreichen?
# 3. Welche Rolle spielt der Whistleblower‑Schutz (Art. 87)?
#
# Speichern Sie Ihre Antworten als `88_art74_87_abschluss.md` in Track_C.
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Infinitivkonstruktionen – Abschluss
#
# Buscha Kap. 6.3, Abschlusstest. Schreiben Sie einen kurzen Aufsatz (1 Seite) über die Bedeutung von Differential Privacy für die Einhaltung des AI Act, in dem Sie ausschließlich Infinitivkonstruktionen verwenden. Speichern Sie als `89_infinitiv_abschluss.md` in Track_C.
#
# **Ausblick auf Woche 15:** Informationstheorie (Entropie, Transinformation), Portfolio‑Zusammenführung, Konformitäts‑Audit, Master‑Bewerbung.
