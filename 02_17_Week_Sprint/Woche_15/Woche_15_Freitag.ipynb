# %% [markdown]
# # Woche 15 – Freitag: Finalisierung des Konformitäts‑Audits & Master‑Bewerbung
#
# ## Block 1 (06:00 – 08:45): Audit – Sanktionen und Selbsterklärung (Art. 99‑101)
#
# **Aufgabe:** Fügen Sie Ihrem Audit ein Kapitel zu Sanktionen hinzu:
# - Welche Sanktionen drohen bei Verstößen?
# - Wie stellt Ihr Unternehmen sicher, dass keine Verstöße auftreten?
# - Fügen Sie eine **Konformitätserklärung** (gemäß Art. 48) hinzu, in der Sie bestätigen, dass das System den Anforderungen entspricht.
#
# Speichern Sie die finale Version des vollständigen Audits als `99_konformitaetsaudit_aml_system_final.md` in Track_C.
#
# > **Verbesserungshinweis:** Die Konformitätserklärung muss vom Management unterzeichnet werden (im Audit reicht eine Platzhalter‑Unterschrift).
#
# ---
#
# ## Block 2 (09:30 – 11:40): Portfolio – Letzte Schritte
#
# **Aufgabe:**
# 1. Erstellen Sie ein **PDF** des Jupyter‑Books (über „Print to PDF“).
# 2. **Pushen Sie alle Änderungen** auf GitHub.
# 3. Überprüfen Sie, ob die `README.md` auf der Hauptseite des Repositories einen klaren Überblick über den Sprint gibt.
# 4. **Erstellen Sie ein Release** (z. B. „v1.0 – 17‑Wochen‑Sprint abgeschlossen“) auf GitHub.
#
# > **Verbesserungshinweis:** Ein GitHub‑Release mit einem ZIP‑Download des gesamten Sprint‑Ordners macht Ihr Portfolio für Arbeitgeber leicht zugänglich.
#
# ---
#
# ## Block 3 (12:40 – 14:10): Master‑Bewerbung – uni‑assist
#
# **Aufgabe:** Bereiten Sie Ihre Bewerbungsunterlagen für den Master „Mathematik für Nachhaltigkeit, Wirtschaft und Data Science“ an der THM Friedberg vor:
# - **Motivationsschreiben** (1‑2 Seiten) – heben Sie hervor, wie der Sprint Sie auf die mathematischen und regulatorischen Anforderungen vorbereitet hat.
# - **Lebenslauf** (aktualisiert)
# - **Zeugnisse** (Bachelor, ggf. Sprachzertifikate)
# - **Passfoto** (falls gefordert)
#
# Speichern Sie alle Dokumente in einem separaten Ordner `Bewerbung_THM` (nicht im Sprint‑Ordner, um die Privatsphäre zu wahren).
#
# > **Verbesserungshinweis:** Die Frist für internationale Bewerber über uni‑assist endet am 15. Juli. Reichen Sie die Unterlagen **mindestens zwei Wochen vorher** ein, da die Bearbeitung Zeit braucht.
#
# ---
#
# ## Block 4 (14:40 – 16:00): SPR – Abschlussreflexion
#
# Verfassen Sie einen abschließenden Bericht (1‑2 Seiten) über Ihren 17‑Wochen‑Sprint. Gehen Sie ein auf:
# - Die wichtigsten Lernerfolge (Mathematik, Python, AI Act, Deutsch)
# - Herausforderungen, die Sie überwunden haben
# - Wie Sie das Gelernte in Ihrem Master und Ihrer Karriere anwenden werden
#
# Speichern Sie den Bericht als `100_abschlussreflexion_sprint.md` in Track_C.
#
# > **Verbesserungshinweis:** Dieser Bericht ist eine hervorragende Grundlage für das Motivationsschreiben oder für zukünftige Bewerbungsgespräche.
#
# **Ausblick auf Woche 16:** Finale Pufferwoche – Wiederholung des gesamten Stoffs, Abschluss des Audits, Bewerbungsabschluss, letzte Feinschliffe am Portfolio.
