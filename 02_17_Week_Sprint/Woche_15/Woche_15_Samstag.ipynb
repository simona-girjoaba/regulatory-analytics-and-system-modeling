# %% [markdown]
# # Woche 15 – Samstag: Leichte Wiederholung & Vorbereitung auf die finale Woche
#
# 1. **Informationstheorie:** Wiederholen Sie die Formeln für Entropie, Transinformation und KL‑Divergenz. Rechnen Sie ein Beispiel per Hand.
# 2. **Portfolio:** Sehen Sie sich Ihr Jupyter‑Book an und korrigieren Sie eventuelle Fehler in der `_toc.yml`.
# 3. **Audit:** Lesen Sie Ihr vollständiges Konformitäts‑Audit von Anfang bis Ende. Markieren Sie Stellen, die noch unklar oder lückenhaft sind, und ergänzen Sie sie.
# 4. **Bewerbung:** Überprüfen Sie Ihre uni‑assist‑Unterlagen auf Vollständigkeit (Checkliste auf der THM‑Webseite).
# 5. **Sprache:** Bilden Sie 10 Sätze mit Infinitivkonstruktionen zu den Themen „Audit“ und „Bewerbung“.
# 6. **Deutsch (Hueber):** Wiederholen Sie alle C2‑Grammatikkapitel (Nominalisierung, Passiv, Partizipialattribute, Relativsätze, Adverbialsätze, Infinitivkonstruktionen, Nomen‑Verb‑Gefüge).
#
# **Reflexion:** Notieren Sie in SPR, welche drei Dinge Sie im Sprint am meisten gelernt haben und welche drei Dinge Sie nach dem Sprint noch vertiefen möchten.
#
# ---
# **Sonntag:** komplett lernfrei.
