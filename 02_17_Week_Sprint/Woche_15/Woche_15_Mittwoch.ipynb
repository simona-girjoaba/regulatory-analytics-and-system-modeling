# %% [markdown]
# # Woche 15 – Mittwoch: Portfolio‑Dokumentation & Audit – Technische Dokumentation
#
# ## Block 1 (06:00 – 08:45): GitHub‑Portfolio finalisieren
#
# **Aufgabe:** Überprüfen Sie Ihre GitHub‑Repository‑Struktur. Stellen Sie sicher, dass:
# - Alle Notebooks aus den Wochen 1‑14 im Ordner `02_17_Week_Sprint` liegen.
# - Die `README.md` im Hauptverzeichnis und in den Unterordnern aktuell ist.
# - Die `cleaned_aml_batch.json` und andere Daten im Repository liegen (oder über relative Pfade erreichbar sind).
# - Sie eine `.gitignore` haben, die unnötige Dateien (`.ipynb_checkpoints`, `__pycache__`, `*.pth`) ausschließt.
#
# **Optional:** Erstellen Sie ein kurzes Video (2‑3 Minuten), in dem Sie die Struktur Ihres Portfolios erklären – das ist eine gute Ergänzung für Bewerbungen.
#
# > **Verbesserungshinweis:** Ein sauberes GitHub‑Portfolio ist oft entscheidend für die erste Einladung zu einem Vorstellungsgespräch.
#
# ---
#
# ## Block 2 (09:30 – 11:40): Python – Letzte Code‑Optimierungen
#
# **Aufgabe:** Gehen Sie alle Ihre Notebooks durch und optimieren Sie:
# - Entfernen Sie unnötige Ausgaben (z. B. `print` in Schleifen).
# - Setzen Sie `random_state` für Reproduzierbarkeit.
# - Fügen Sie Kommentare hinzu, wo nötig.
# - Achten Sie auf PEP8 (z. B. Leerzeichen nach Kommata).
#
# Erstellen Sie ein **Zusammenfassungs‑Notebook** `00_Sprint_Zusammenfassung.ipynb`, das die wichtigsten Code‑Blöcke aus den Wochen enthält (PCA, Autoencoder, FL, SHAP, DP).
#
# > **Verbesserungshinweis:** Ein übersichtliches, gut kommentiertes Notebook zeigt Ihre Professionalität.
#
# ---
#
# ## Block 3 (12:40 – 14:10): Audit – Technische Dokumentation (Art. 11) ausfüllen
#
# **Aufgabe:** Nehmen Sie Ihr Template für die technische Dokumentation aus Woche 5 und füllen Sie es konkret für Ihren Autoencoder aus. Gehen Sie ein auf:
# - Allgemeine Beschreibung (Zweck, Funktionsweise)
# - Datenbeschreibung (Quellen, Verarbeitung, Schutzmaßnahmen)
# - Risikobewertung (welche Fehler können auftreten?)
# - Konformitätsbewertung (wie wurde sie durchgeführt?)
#
# Speichern Sie die ausgefüllte technische Dokumentation als `93_technische_dokumentation_audit.md` in Track_C.
#
# > **Verbesserungshinweis:** Die technische Dokumentation ist ein zentraler Bestandteil des Audits – sie muss für Aufsichtsbehörden zugänglich sein.
#
# ---
#
# ## Block 4 (14:40 – 16:50): SPR – Audit – Grundrechte‑Folgenabschätzung (Art. 27) finalisieren
#
# Nehmen Sie Ihre Grundrechte‑Folgenabschätzung aus Woche 10 und aktualisieren Sie sie mit den Erkenntnissen der letzten Wochen. Gehen Sie besonders ein auf:
# - Datenschutz (durch Differential Privacy und Verschlüsselung)
# - Diskriminierungsrisiken (durch XAI überwachbar)
# - Transparenz (Art. 50)
#
# Speichern Sie die finale Version als `94_grundrechte_folgenabschaetzung_final.md` in Track_C.
#
# > **Verbesserungshinweis:** Die Folgenabschätzung muss vor der Inbetriebnahme des Systems durchgeführt und regelmäßig aktualisiert werden.
