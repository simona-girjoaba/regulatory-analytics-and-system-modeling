# %% [markdown]
# # Woche 7 – Samstag: Wiederholung Zeitreihen & AI Act
#
# 1. **Mathematik:** Wiederholen Sie die Konzepte Trend, Saison, Residuum. Erstellen Sie eine Mindmap in STEM.
# 2. **Python:** Laden Sie einen beliebigen Zeitreihendatensatz (z. B. Temperaturdaten) und führen Sie eine ARIMA‑Analyse durch (ACF, PACF, Modellauswahl, Prognose).
# 3. **Governance:** Lesen Sie Ihren Bericht über die notifizierte Stelle und überlegen Sie, ob Ihr fiktives AML‑System eher interne Konformitätsbewertung oder externe Zertifizierung benötigt.
# 4. **Sprache:** Bilden Sie 10 Sätze mit Adverbialsätzen zu den Themen „Zertifizierung von KI“ und „Zeitreihenprognose“.
# 5. **Deutsch (Hueber):** Lektion zu Adverbialsätzen wiederholen (Wortschatz & Grammatik C2).
#
# **Reflexion:** Notieren Sie in SPR, welche Schwierigkeiten Sie bei der Zeitreihenanalyse hatten und wie Sie diese überwinden können.
#
# ---
# **Sonntag:** komplett lernfrei.
