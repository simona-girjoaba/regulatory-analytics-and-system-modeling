# %% [markdown]
# # Woche 1 – Montag: Vektorraumaxiome & NumPy‑Tensoren
#
# ## Block 1 (06:00 – 08:45): Vektorraumaxiome
#
# **Lernziel:** Sie können die acht Axiome eines Vektorraums benennen, auf Beispiele anwenden und in Python (NumPy) überprüfen.
#
# ### 1.1 Definition eines Vektorraums
#
# Ein Vektorraum über dem Körper $\mathbb{R}$ (den reellen Zahlen) ist eine nichtleere Menge $V$, ausgestattet mit einer **Addition** $+: V \times V \to V$ und einer **Skalarmultiplikation** $\cdot: \mathbb{R} \times V \to V$. Diese Abbildungen garantieren die **Abgeschlossenheit** (Ergebnisse liegen zwingend wieder in $V$). Darauf aufbauend müssen die folgenden acht Axiome gelten.
#
# ---
#
# **Axiom 1: Kommutativität der Addition**
#
# $$u + v = v + u \qquad \forall u,v \in V$$
#
# ---
#
# **Axiom 2: Assoziativität der Addition**
#
# $$(u + v) + w = u + (v + w) \qquad \forall u,v,w \in V$$
#
# ---
#
# **Axiom 3: Existenz des neutralen Elements (Nullvektor)**
#
# $$\exists 0 \in V \; \forall v \in V : v + 0 = v$$
#
# ---
#
# **Axiom 4: Existenz des inversen Elements**
#
# $$\forall v \in V \; \exists (-v) \in V : v + (-v) = 0$$
#
# ---
#
# **Axiom 5: Neutralität der skalaren Eins**
#
# $$1 \cdot v = v \qquad \forall v \in V$$
#
# ---
#
# **Axiom 6: Assoziativität der Skalarmultiplikation**
#
# $$a \cdot (b \cdot v) = (ab) \cdot v \qquad \forall a,b \in \mathbb{R}, v \in V$$
#
# ---
#
# **Axiom 7: Distributivität der Skalarmultiplikation bzgl. der Vektoraddition**
#
# $$a \cdot (u + v) = a \cdot u + a \cdot v \qquad \forall a \in \mathbb{R}, u,v \in V$$
#
# ---
#
# **Axiom 8: Distributivität der Skalaraddition bzgl. der Vektormultiplikation**
#
# $$(a + b) \cdot v = a \cdot v + b \cdot v \qquad \forall a,b \in \mathbb{R}, v \in V$$
#
# ---

# %%
import numpy as np

# Initialisierung im reellen Körper (Floats)
u = np.array([1.0, 2.0])
v = np.array([3.0, 4.0])
w = np.array([5.0, 6.0])
a, b = 2.0, 3.0
zero = np.zeros_like(u)

# Verifikation durch assertions (np.allclose für Float-Toleranz)
assert np.allclose(u + v, v + u), "Axiom 1 (Kommutativität) verletzt"
assert np.allclose((u + v) + w, u + (v + w)), "Axiom 2 (Assoziativität) verletzt"
assert np.allclose(u + zero, u), "Axiom 3 (Nullvektor) verletzt"
assert np.allclose(u + (-u), zero), "Axiom 4 (Inverses Element) verletzt"

assert np.allclose(1 * u, u), "Axiom 5 (Skalare Eins) verletzt"
assert np.allclose(a * (b * u), (a * b) * u), "Axiom 6 (Skalare Assoziativität) verletzt"
assert np.allclose(a * (u + v), a * u + a * v), "Axiom 7 (Distributivität I) verletzt"
assert np.allclose((a + b) * u, a * u + b * u), "Axiom 8 (Distributivität II) verletzt"

print("Alle 8 Vektorraumaxiome erfolgreich maschinell verifiziert.")
# Out:
# Alle 8 Vektorraumaxiome erfolgreich maschinell verifiziert.

# %% [markdown]
# ## Block 2 (09:30 – 11:40): Einführung in NumPy‑Tensoren
#
# **Lernziel:** Sie können 0D‑, 1D‑ und 2D‑Tensoren mit NumPy erzeugen, deren `shape` und `dtype` kontrollieren sowie elementare Reduktionsoperationen entlang spezifischer Achsen durchführen.
#
# ### 2.1 Tensor-Dimensionen und Datenstruktur-Mapping
#
# In der Datenanalyse repräsentieren Tensoren konkrete Datenstrukturen:
# * **0D (Skalar):** Einzelner Messwert (z.B. ein Temperaturwert).
# * **1D (Vektor):** Eindimensionale Sequenz (z.B. eine Zeitreihe oder ein Feature-Vektor).
# * **2D (Matrix):** Tabellarische Daten (Zeilen = Beobachtungen/Samples, Spalten = Features/Merkmale).

# %%
import numpy as np

# Instanziierung unter expliziter Angabe des Datentyps (dtype)
s = np.array(5, dtype=np.int32)       # 0D
v = np.array([1.0, 2.0, 3.0])         # 1D (Float implizit durch Dezimalpunkt)
M = np.array([[1, 2], [3, 4]])        # 2D

# Verifikation von Dimensionen (shape) und Typen (dtype)
assert s.shape == () and s.dtype == np.int32
assert v.shape == (3,) and v.dtype == np.float64
assert M.shape == (2, 2)

# Effiziente Initialisierungsfunktionen für Platzhalter
zeros = np.zeros((3, 3))
ones = np.ones((2, 4))

# %% [markdown]
# ### 2.2 Achsenbasierte Reduktionsoperationen
# Reduktionen (wie .sum() oder .mean()) aggregieren Daten entlang einer definierten Achse (axis). Die resultierende Dimension verliert exakt die kollabierte Achse.

# %%
# Skalar (0D)
A = np.array([[1, 2],
              [3, 4]])

# Globale Reduktion (kollabiert den gesamten Tensor zu einem Skalar)
assert A.sum() == 10

# Reduktion über Achse 0 (kollabiert Zeilen, summiert Spaltenwerte)
assert np.array_equal(A.sum(axis=0), [4, 6])

# Reduktion über Achse 1 (kollabiert Spalten, summiert Zeilenwerte)
assert np.array_equal(A.sum(axis=1), [3, 7])

# %% [markdown]
# ### 2.3 Systematische Übung: 3D-Tensoren
# Ein 3D-Tensor (axis=0, 1, 2) repräsentiert typischerweise Bilddaten (Farbkanäle, Höhe, Breite) oder Daten-Batches.
#
# Aufgabe: Erzeugen Sie einen 3D‑Tensor der Form (2,3,4) mit np.random.rand. Berechnen Sie die Summe entlang jeder Achse und verifizieren Sie maschinell die resultierenden Dimensionen.

# %%
# Reproduzierbarkeit der Zufallszahlen sicherstellen
np.random.seed(42)

# Erzeugung: 2 Batches, 3 Zeilen, 4 Spalten
rand3d = np.random.rand(2, 3, 4)

# Analyse des Dimensionsabbaus
assert rand3d.sum(axis=0).shape == (3, 4), "Fehler: Batches nicht korrekt aggregiert"
assert rand3d.sum(axis=1).shape == (2, 4), "Fehler: Zeilen nicht korrekt aggregiert"
assert rand3d.sum(axis=2).shape == (2, 3), "Fehler: Spalten nicht korrekt aggregiert"

print("Alle 3D-Reduktionsdimensionen erfolgreich verifiziert.")
# Out:
# Alle 3D-Reduktionsdimensionen erfolgreich verifiziert.

# %% [markdown]
# ## Block 3 (12:40 – 14:10): AI Act – Artikel 1 und 2 (Geltungsbereich)
#
# **Lernziel:** Sie können die Anwendbarkeit der EU‑KI‑Verordnung auf spezifische Systemarchitekturen anhand des räumlichen und sachlichen Geltungsbereichs systematisch evaluieren.
#
# ### 3.1 Rechtlicher Rahmen
# * **Art. 1 (Gegenstand):** Harmonisierung des Inverkehrbringens, der Inbetriebnahme und der Nutzung von KI‑Systemen zur Gewährleistung von Gesundheit, Sicherheit und Grundrechten.
# * **Art. 2 (Anwendungsbereich):** * *Räumlich:* Gilt bei Bereitstellung oder Nutzung in der EU (Extraterritorialitätsprinzip).
#   * *Sachlich:* Umfasst Anbieter, Betreiber, Importeure und Händler.
#   * *Ausnahmen:* Militär, nationale Sicherheit, reine Grundlagenforschung.
#
# ### 3.2 Compliance-Prüfung (GOV NotebookLM)
# **Aufgabe:** Erstellen Sie eine binäre Prüfmatrix für das geplante „AML-Transaktions-Scoring-System“ der Bank. Dokumentieren Sie die Begründung für die Subsumtion unter den AI Act.
#
# | Prüfkriterium | Zutreffend (J/N) | Begründung (Beispiel AML-System) |
# | :--- | :--- | :--- |
# | **KI-System laut Definition?** | J | System nutzt maschinelles Lernen zur Mustererkennung. |
# | **Markteinführung/Nutzung in EU?** | J | Einsatzgebiet ist die europäische Niederlassung der Bank. |
# | **Gewerblicher Zweck?** | J | Risikominimierung im operativen Bankgeschäft (keine Forschung). |
# | **Fazit:** | **Voll anwendbar** | Das System fällt unter die Pflichten des AI Acts. |
#
# ---
#
# ## Block 4 (14:40 – 16:50): Formelle Compliance-Kommunikation
#
# **Lernziel:** Sie können rechtliche Sachverhalte (hier: Art. 4 AI Act) in der internen Geschäftskommunikation durch gezielten Einsatz des Nominalstils hochverdichtet und präzise adressieren.
#
# **Ressource:** *Entscheidungen, Deutsch als Geschäfts‑ und Verhandlungssprache* (S. 12‑18).
#
# ### 4.1 Systematische Schreibübung: E-Mail an die Rechtsabteilung
# Verfassen Sie eine formelle E‑Mail an die Rechtsabteilung der fiktiven „Deutsche FinTech AG“.
#
# **Vorgaben & Restriktionen:**
# 1. **Thema:** Einholung einer juristischen Einschätzung zur Auslegung der „KI-Kompetenz“-Pflichten (Art. 4 AI Act) für das IT-Audit-Team.
# 2. **Stilvorgabe (Nominalisierung):** Wandeln Sie prozessuale Beschreibungen zwingend in Nomen um, um die formelle Tonalität zu wahren.
# 3. **Struktur:** Betreffzeile, formelle Anrede, Situationsbeschreibung, konkrete Handlungsaufforderung (Call to Action), formelle Grußformel.
# 4. **Wortlimit:** Maximal 150 Wörter.
#
# **Referenzbeispiele zur Kalibrierung:**
#
# * *Beispiel 1 (Verboten/Verbal):* „Wir müssen prüfen, ob die Mitarbeiter die Warnungen der KI verstehen.“
#
#   *Erzwungen/Nominal:* „Die Prüfung des Mitarbeiterverständnisses hinsichtlich der KI-generierten Warnmeldungen ist erforderlich.“
#
# * *Beispiel 2 (Verboten/Verbal):* „Wir bitten Sie zu prüfen, ob die aktuellen Schulungen ausreichen.“
#
#   *Erzwungen/Nominal:* „Es ergeht die Bitte um juristische Prüfung der Angemessenheit bestehender Schulungsmaßnahmen.“
#
# **Speicherort:** `01_Master_Curriculum_DS_ML/Track_C_Governance_and_Compliance/01_email_ki_kompetenz.md`
